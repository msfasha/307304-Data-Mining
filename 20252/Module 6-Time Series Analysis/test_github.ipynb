# %% [markdown]
# Testing Jupyter on Github

# %%
import numpy as np

myarr = np.zeros((10, 10), dtype=int)

# %%
myarr = np.random.randint(0, 101, size=(10, 10))

# %%
myarr
# Out:
# array([[ 46,  50,  76,  86,  89,  79,  31, 100,  39,  61],
#        [ 60,  28,  10,  12,  23,  47,  97,  89,  35,  95],
#        [ 16,  68,  85,  14,  62,  43,  68,  49,   9,   9],
#        [ 53,   3,  71,  40,  49,  47,  43,   7,  58,  44],
#        [ 81,  26,  83,  53,  97,  60,   9,   3,  57,   6],
#        [ 64,  72,  79,  30,  77,  42,  11,   8,  33,   0],
#        [ 81,   3,  21,  94,  50,  86,  95,  69,  70,  19],
#        [ 34,  61,  83,  57,  81,  32,  62,  18,  33,  52],
#        [ 24,  79,  44,  14,   3,  80,  96,  52,  40,  24],
#        [ 34,  71,   7,   8,  69,  54,  21,  96,  59,  15]])
